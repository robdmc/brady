# %% [markdown]
# # This is the new Extractor Code

# %%
import requests
import json

url = 'xxx'
user = 'xxx'
pwd = 'xxx'

response = requests.get(url, auth=(user, pwd))

data = response.json()

tickets = data['tickets']


def extract_one(blob, *keys, transformer=None):
    """
    This function will extract the value at the nested "path" supplied
    by the *keys arguments.

    if transformer is a function, than this function will be run on the
    item located at the specified path.
    """
    # Make sure the user passes at least one key to extract
    if len(keys) == 0:
        raise ValueError('You must supply at least one key')

    # If only one key passed, then just grab the entry at that key
    if len(keys) == 1:
        # BUT... if a tranformer is supplied, run the transformer on the value at that key
        if transformer:
            return transformer(blob.get(keys[0]))
        else:
            return blob.get(keys[0])
    # If there is more than one key, then you know you are not yet at the address you need
    # Descend the path tree to the next key in the "address list"
    else:
        sub_blob = blob[keys[0]]

        # Recursively call this same function with the remaining addresses on the chain
        return extract_one(sub_blob, *keys[1:], transformer=transformer)


def get_total_seconds(iterable):
    """
    This is a special transformer function that we will use to extract the total seconds
    from the blob.  You can pass transformer functions to do special logic that is
    required other than simply pulling out nested keys.
    """
    custom_field_id = 360016643492

    if not isinstance(iterable, list):
        return iterable

    # I know this input will be a list, so just iterate over it
    for item in iterable:
        # If I've found the item id I care about, return it
        if item['id'] == custom_field_id:
            # Grab the value and transform it to an integer if it's a string
            out = item['value']
            if isinstance(out, str):
                out = int(out)
            # return the value
            return out

    # The only way you make it here is if this record didn't find the custom field you want
    raise ValueError(f"Uh oh! I couldn't find the custom field id {custom_field_id}")


def extract_from_ticket(ticket):
    return {
        'assignee_id': extract_one(ticket, 'assignee_id'),
        'url': extract_one(ticket, 'url'),
        'id': extract_one(ticket, 'id'),
        'status': extract_one(ticket, 'status'),
        'created_at': extract_one(ticket, 'created_at'),
        'total_seconds': extract_one(ticket, 'custom_fields', transformer=get_total_seconds),
        'satisfaction_rating': extract_one(ticket, 'satisfaction_rating', 'score')
    }

from pprint import pprint
records = [extract_from_ticket(t) for t in tickets]
pprint(records)
# Out:
# [{'assignee_id': 380454819451,
#   'created_at': '2021-05-18T12:54:23Z',
#   'id': 50822,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1007,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50822.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-17T07:29:13Z',
#   'id': 50815,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 2207,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50815.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-10T07:58:25Z',
#   'id': 50755,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 993,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50755.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-07T08:14:14Z',
#   'id': 50740,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 8657,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50740.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-14T13:18:00Z',
#   'id': 50802,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 2483,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50802.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-04-21T13:40:24Z',
#   'id': 50579,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 851,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50579.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-13T16:11:02Z',
#   'id': 50793,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 496,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50793.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-10T18:28:34Z',
#   'id': 50762,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 8895,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50762.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-04-21T14:40:28Z',
#   'id': 50580,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 2992,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50580.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-14T16:19:41Z',
#   'id': 50808,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 265,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50808.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-25T19:41:57Z',
#   'id': 50892,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50892.json'},
#  {'assignee_id': None,
#   'created_at': '2021-05-13T16:23:18Z',
#   'id': 50795,
#   'satisfaction_rating': 'unoffered',
#   'status': 'hold',
#   'total_seconds': 1254,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50795.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-18T20:22:50Z',
#   'id': 50827,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 851,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50827.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-18T17:28:48Z',
#   'id': 50824,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 442,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50824.json'},
#  {'assignee_id': None,
#   'created_at': '2021-04-26T13:29:47Z',
#   'id': 50621,
#   'satisfaction_rating': 'unoffered',
#   'status': 'deleted',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50621.json'},
#  {'assignee_id': None,
#   'created_at': '2021-04-26T14:09:57Z',
#   'id': 50623,
#   'satisfaction_rating': 'unoffered',
#   'status': 'deleted',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50623.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-07T09:29:48Z',
#   'id': 50741,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 3526,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50741.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-19T15:17:52Z',
#   'id': 50834,
#   'satisfaction_rating': 'good',
#   'status': 'closed',
#   'total_seconds': 797,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50834.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-26T17:57:43Z',
#   'id': 50914,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50914.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-06T17:56:41Z',
#   'id': 50729,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 4979,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50729.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-17T15:13:13Z',
#   'id': 50818,
#   'satisfaction_rating': 'good',
#   'status': 'closed',
#   'total_seconds': 6191,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50818.json'},
#  {'assignee_id': None,
#   'created_at': '2021-05-25T19:59:13Z',
#   'id': 50895,
#   'satisfaction_rating': 'unoffered',
#   'status': 'hold',
#   'total_seconds': 1293,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50895.json'},
#  {'assignee_id': None,
#   'created_at': '2021-05-16T18:39:22Z',
#   'id': 50812,
#   'satisfaction_rating': 'unoffered',
#   'status': 'hold',
#   'total_seconds': 2341,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50812.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-04-19T17:13:40Z',
#   'id': 50555,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 4209,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50555.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-03-16T11:21:23Z',
#   'id': 50156,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': 12386,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50156.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-20T09:10:35Z',
#   'id': 50843,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 89,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50843.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-13T21:02:41Z',
#   'id': 50799,
#   'satisfaction_rating': 'good',
#   'status': 'closed',
#   'total_seconds': 442,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50799.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-27T12:49:56Z',
#   'id': 50919,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50919.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-19T21:44:12Z',
#   'id': 50841,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 795,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50841.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-19T19:12:00Z',
#   'id': 50838,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 3178,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50838.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-18T23:23:49Z',
#   'id': 50830,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 740,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50830.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-04-09T20:47:38Z',
#   'id': 50453,
#   'satisfaction_rating': 'unoffered',
#   'status': 'pending',
#   'total_seconds': 2258,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50453.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-14T15:19:44Z',
#   'id': 50806,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 150,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50806.json'},
#  {'assignee_id': 376700694172,
#   'created_at': '2019-12-04T14:42:53Z',
#   'id': 44952,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 6446,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/44952.json'},
#  {'assignee_id': None,
#   'created_at': '2021-05-10T15:07:37Z',
#   'id': 50757,
#   'satisfaction_rating': 'unoffered',
#   'status': 'hold',
#   'total_seconds': 203,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50757.json'},
#  {'assignee_id': None,
#   'created_at': '2021-05-12T19:13:28Z',
#   'id': 50787,
#   'satisfaction_rating': 'unoffered',
#   'status': 'hold',
#   'total_seconds': 5501,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50787.json'},
#  {'assignee_id': None,
#   'created_at': '2021-04-27T16:33:37Z',
#   'id': 50643,
#   'satisfaction_rating': 'unoffered',
#   'status': 'deleted',
#   'total_seconds': 0,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50643.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-20T19:43:29Z',
#   'id': 50852,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 337,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50852.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-19T16:08:20Z',
#   'id': 50835,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 6075,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50835.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-14T00:55:52Z',
#   'id': 50800,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 2662,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50800.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-19T16:48:34Z',
#   'id': 50836,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 485,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50836.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-14T15:51:33Z',
#   'id': 50807,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1932,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50807.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-21T14:08:40Z',
#   'id': 50857,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 780,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50857.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-21T16:16:35Z',
#   'id': 50862,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 520,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50862.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-19T13:59:50Z',
#   'id': 50833,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 5352,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50833.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-21T14:43:07Z',
#   'id': 50858,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 573,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50858.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-18T21:58:24Z',
#   'id': 50829,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 2611,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50829.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-20T17:10:10Z',
#   'id': 50846,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 2430,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50846.json'},
#  {'assignee_id': None,
#   'created_at': '2021-04-29T19:05:38Z',
#   'id': 50663,
#   'satisfaction_rating': 'unoffered',
#   'status': 'deleted',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50663.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-24T12:57:27Z',
#   'id': 50866,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 836,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50866.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-24T11:48:11Z',
#   'id': 50864,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': 525,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50864.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-19T19:25:58Z',
#   'id': 50839,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': 633,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50839.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-24T12:38:14Z',
#   'id': 50865,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 228,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50865.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-24T16:16:45Z',
#   'id': 50868,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1173,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50868.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-21T13:22:02Z',
#   'id': 50855,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 392,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50855.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-20T23:10:54Z',
#   'id': 50854,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 706,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50854.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-04-06T17:03:28Z',
#   'id': 50403,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 6457,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50403.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-24T22:05:28Z',
#   'id': 50874,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 103,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50874.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-25T12:49:50Z',
#   'id': 50879,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1110,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50879.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-20T20:26:55Z',
#   'id': 50853,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 170,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50853.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-20T19:37:31Z',
#   'id': 50851,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 871,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50851.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-20T14:51:37Z',
#   'id': 50844,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1537,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50844.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-25T09:39:44Z',
#   'id': 50877,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 477,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50877.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-04T20:45:46Z',
#   'id': 50704,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1748,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50704.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-25T16:30:14Z',
#   'id': 50885,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 415,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50885.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-25T14:19:47Z',
#   'id': 50881,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1114,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50881.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-25T16:21:07Z',
#   'id': 50884,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': 83,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50884.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-25T19:54:36Z',
#   'id': 50893,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 140,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50893.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-25T19:28:38Z',
#   'id': 50891,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': 42,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50891.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-20T19:27:57Z',
#   'id': 50849,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 2582,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50849.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-17T13:28:36Z',
#   'id': 50816,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 3792,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50816.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-04-20T15:45:05Z',
#   'id': 50563,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 634,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50563.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-04-20T14:44:40Z',
#   'id': 50562,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1494,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50562.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-03T12:30:48Z',
#   'id': 50677,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 2706,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50677.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-25T23:48:19Z',
#   'id': 50902,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1139,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50902.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-18T09:59:39Z',
#   'id': 50821,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 3044,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50821.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-25T01:09:59Z',
#   'id': 50875,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1425,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50875.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-26T17:36:14Z',
#   'id': 50913,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 21,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50913.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-26T14:36:54Z',
#   'id': 50910,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 372,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50910.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-25T19:11:06Z',
#   'id': 50890,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 361,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50890.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-02T19:43:48Z',
#   'id': 50956,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50956.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-03T22:55:52Z',
#   'id': 50694,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1990,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50694.json'},
#  {'assignee_id': None,
#   'created_at': '2021-06-03T04:31:42Z',
#   'id': 50958,
#   'satisfaction_rating': 'unoffered',
#   'status': 'deleted',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50958.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-24T01:30:32Z',
#   'id': 50863,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 5207,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50863.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-26T13:57:26Z',
#   'id': 50909,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1900,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50909.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-27T14:44:36Z',
#   'id': 50922,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1228,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50922.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-03T16:39:33Z',
#   'id': 50966,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50966.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-03T17:41:16Z',
#   'id': 50967,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50967.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-25T14:24:24Z',
#   'id': 50882,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1083,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50882.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-27T17:28:13Z',
#   'id': 50926,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 2374,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50926.json'},
#  {'assignee_id': None,
#   'created_at': '2021-06-03T18:34:27Z',
#   'id': 50968,
#   'satisfaction_rating': 'unoffered',
#   'status': 'deleted',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50968.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-14T18:44:22Z',
#   'id': 50809,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 582,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50809.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-03-04T21:50:20Z',
#   'id': 50056,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 4901,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50056.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-14T15:01:22Z',
#   'id': 50804,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 18188,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50804.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-03-03T18:10:49Z',
#   'id': 50034,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1506,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50034.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-05T17:30:38Z',
#   'id': 50714,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 8366,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50714.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-03-19T14:36:33Z',
#   'id': 50209,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1824,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50209.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-25T14:39:14Z',
#   'id': 50883,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 4671,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50883.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-27T14:39:58Z',
#   'id': 50921,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 3209,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50921.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-27T16:27:49Z',
#   'id': 50925,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 308,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50925.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-03-18T15:30:04Z',
#   'id': 50190,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 4008,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50190.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-04-15T17:05:52Z',
#   'id': 50526,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1356,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50526.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-27T21:48:07Z',
#   'id': 50928,
#   'satisfaction_rating': 'unoffered',
#   'status': 'solved',
#   'total_seconds': 76,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50928.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-27T15:00:15Z',
#   'id': 50923,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': 623,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50923.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-28T13:06:48Z',
#   'id': 50931,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': 542,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50931.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-25T19:57:15Z',
#   'id': 50894,
#   'satisfaction_rating': 'good',
#   'status': 'closed',
#   'total_seconds': 4398,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50894.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-25T17:09:39Z',
#   'id': 50887,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1003,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50887.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-28T15:42:28Z',
#   'id': 50932,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 717,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50932.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-26T13:14:14Z',
#   'id': 50907,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 846,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50907.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-26T12:44:29Z',
#   'id': 50906,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 2088,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50906.json'},
#  {'assignee_id': None,
#   'created_at': '2021-05-07T16:53:18Z',
#   'id': 50748,
#   'satisfaction_rating': 'unoffered',
#   'status': 'deleted',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50748.json'},
#  {'assignee_id': None,
#   'created_at': '2021-05-07T16:53:19Z',
#   'id': 50749,
#   'satisfaction_rating': 'unoffered',
#   'status': 'deleted',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50749.json'},
#  {'assignee_id': None,
#   'created_at': '2021-05-07T16:53:20Z',
#   'id': 50750,
#   'satisfaction_rating': 'unoffered',
#   'status': 'deleted',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50750.json'},
#  {'assignee_id': None,
#   'created_at': '2021-05-07T16:53:12Z',
#   'id': 50747,
#   'satisfaction_rating': 'unoffered',
#   'status': 'deleted',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50747.json'},
#  {'assignee_id': None,
#   'created_at': '2021-06-07T15:50:26Z',
#   'id': 50987,
#   'satisfaction_rating': 'unoffered',
#   'status': 'deleted',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50987.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-07T16:03:42Z',
#   'id': 50988,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50988.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-07T20:43:41Z',
#   'id': 50995,
#   'satisfaction_rating': 'unoffered',
#   'status': 'solved',
#   'total_seconds': 66,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50995.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-27T03:34:48Z',
#   'id': 50918,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 6273,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50918.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-01T02:11:53Z',
#   'id': 50935,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 321,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50935.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-27T15:17:18Z',
#   'id': 50924,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 917,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50924.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-25T02:03:56Z',
#   'id': 50876,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 2411,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50876.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-24T17:35:39Z',
#   'id': 50870,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 3618,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50870.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-01T15:41:32Z',
#   'id': 50941,
#   'satisfaction_rating': 'good',
#   'status': 'closed',
#   'total_seconds': 288,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50941.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-26T18:49:17Z',
#   'id': 50915,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 3297,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50915.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-01T15:28:46Z',
#   'id': 50940,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1562,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50940.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-01T18:27:47Z',
#   'id': 50943,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1105,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50943.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-26T15:09:32Z',
#   'id': 50911,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 2524,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50911.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-07T14:20:38Z',
#   'id': 50744,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': 1487,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50744.json'},
#  {'assignee_id': None,
#   'created_at': '2021-06-09T02:30:31Z',
#   'id': 51021,
#   'satisfaction_rating': 'unoffered',
#   'status': 'deleted',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51021.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-09T13:21:55Z',
#   'id': 51024,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51024.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-01T05:19:04Z',
#   'id': 50936,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 602,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50936.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-02T12:17:25Z',
#   'id': 50946,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 368,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50946.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-25T23:37:29Z',
#   'id': 50901,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': 1145,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50901.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-09T14:38:08Z',
#   'id': 51028,
#   'satisfaction_rating': 'unoffered',
#   'status': 'solved',
#   'total_seconds': 26,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51028.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-07T21:43:48Z',
#   'id': 50996,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 443,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50996.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-26T12:12:50Z',
#   'id': 50904,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 3807,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50904.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-26T13:48:09Z',
#   'id': 50908,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 636,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50908.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-26T16:15:14Z',
#   'id': 50912,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 2653,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50912.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-02T12:42:14Z',
#   'id': 50947,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 650,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50947.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-02T14:45:20Z',
#   'id': 50949,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 960,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50949.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-03T10:53:12Z',
#   'id': 50960,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': 1427,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50960.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-02T14:38:39Z',
#   'id': 50948,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 239,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50948.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-02T15:44:42Z',
#   'id': 50951,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 46,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50951.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-02T15:12:16Z',
#   'id': 50950,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': 433,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50950.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-25T21:09:17Z',
#   'id': 50899,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1599,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50899.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-02T18:44:15Z',
#   'id': 50953,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1530,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50953.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-28T18:28:44Z',
#   'id': 50933,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1642,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50933.json'},
#  {'assignee_id': None,
#   'created_at': '2021-06-10T11:54:07Z',
#   'id': 51041,
#   'satisfaction_rating': 'unoffered',
#   'status': 'deleted',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51041.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-07T20:05:25Z',
#   'id': 50994,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': 1418,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50994.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-26T18:56:17Z',
#   'id': 50916,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1300,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50916.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-01T00:24:57Z',
#   'id': 50934,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 525,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50934.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-19T17:16:26Z',
#   'id': 50837,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 5736,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50837.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-20T18:26:17Z',
#   'id': 50847,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1247,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50847.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-25T09:43:20Z',
#   'id': 50878,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 4014,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50878.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-03T16:39:24Z',
#   'id': 50965,
#   'satisfaction_rating': 'good',
#   'status': 'closed',
#   'total_seconds': 1051,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50965.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-02T18:35:33Z',
#   'id': 50952,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': 385,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50952.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-13T18:44:46Z',
#   'id': 50797,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': 239,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50797.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-03-23T16:00:54Z',
#   'id': 50244,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 479,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50244.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-26T21:25:08Z',
#   'id': 50917,
#   'satisfaction_rating': 'unoffered',
#   'status': 'pending',
#   'total_seconds': 890,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50917.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-11T14:05:38Z',
#   'id': 51056,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51056.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-25T16:54:53Z',
#   'id': 50886,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 896,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50886.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-28T12:42:48Z',
#   'id': 50930,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 406,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50930.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-04T13:32:21Z',
#   'id': 50974,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1197,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50974.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-04T16:00:08Z',
#   'id': 50975,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 187,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50975.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-04T18:13:19Z',
#   'id': 50979,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 280,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50979.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-14T15:17:13Z',
#   'id': 50805,
#   'satisfaction_rating': 'good',
#   'status': 'closed',
#   'total_seconds': 12834,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50805.json'},
#  {'assignee_id': None,
#   'created_at': '2021-01-11T22:01:11Z',
#   'id': 49510,
#   'satisfaction_rating': 'unoffered',
#   'status': 'hold',
#   'total_seconds': 3212,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/49510.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-04T16:02:22Z',
#   'id': 50976,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 529,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50976.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-01T15:14:09Z',
#   'id': 50938,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 278,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50938.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-25T13:47:24Z',
#   'id': 50880,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 889,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50880.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-07T13:48:48Z',
#   'id': 50983,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 382,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50983.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-07T18:45:21Z',
#   'id': 50992,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': 692,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50992.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-04-12T20:18:00Z',
#   'id': 50473,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 2885,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50473.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-03T15:29:22Z',
#   'id': 50964,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 159,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50964.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-07T18:54:22Z',
#   'id': 50993,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 228,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50993.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-07T16:30:04Z',
#   'id': 50991,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 366,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50991.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-07T14:55:41Z',
#   'id': 50986,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 910,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50986.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-24T16:55:17Z',
#   'id': 50869,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 4558,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50869.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-11T17:08:26Z',
#   'id': 50772,
#   'satisfaction_rating': 'good',
#   'status': 'closed',
#   'total_seconds': 4747,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50772.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-14T14:47:16Z',
#   'id': 50803,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 3776,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50803.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-15T03:19:25Z',
#   'id': 51071,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51071.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-21T13:47:13Z',
#   'id': 50856,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 5497,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50856.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-07T14:50:35Z',
#   'id': 50985,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 499,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50985.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-08T13:17:08Z',
#   'id': 51004,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 407,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51004.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-08T09:43:31Z',
#   'id': 51003,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 567,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51003.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-07T16:07:20Z',
#   'id': 50989,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 157,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50989.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-01T15:26:32Z',
#   'id': 50939,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1139,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50939.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-15T15:48:23Z',
#   'id': 51077,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51077.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-08T14:33:50Z',
#   'id': 51008,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1956,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51008.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-15T16:20:29Z',
#   'id': 51078,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51078.json'},
#  {'assignee_id': None,
#   'created_at': '2021-06-15T17:01:53Z',
#   'id': 51079,
#   'satisfaction_rating': 'unoffered',
#   'status': 'deleted',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51079.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-06-08T15:09:50Z',
#   'id': 51011,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1302,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51011.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-03T07:06:05Z',
#   'id': 50959,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 5034,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50959.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-07T22:32:03Z',
#   'id': 50999,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 667,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50999.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-08T18:25:37Z',
#   'id': 51015,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 227,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51015.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-04T17:39:51Z',
#   'id': 50977,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 531,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50977.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-03-22T20:19:26Z',
#   'id': 50234,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': 14769,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50234.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-08T20:49:37Z',
#   'id': 51018,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': 120,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51018.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-06T20:37:43Z',
#   'id': 50732,
#   'satisfaction_rating': 'unoffered',
#   'status': 'open',
#   'total_seconds': 607,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50732.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-08T22:51:13Z',
#   'id': 51020,
#   'satisfaction_rating': 'good',
#   'status': 'closed',
#   'total_seconds': 131,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51020.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-08T00:00:05Z',
#   'id': 51001,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1030,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51001.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-06-03T13:11:58Z',
#   'id': 50962,
#   'satisfaction_rating': 'unoffered',
#   'status': 'open',
#   'total_seconds': 857,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50962.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-25T21:01:41Z',
#   'id': 50897,
#   'satisfaction_rating': 'unoffered',
#   'status': 'pending',
#   'total_seconds': 11132,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50897.json'},
#  {'assignee_id': 380454819451,
# ...
#   'created_at': '2021-06-17T03:20:37Z',
#   'id': 51100,
#   'satisfaction_rating': 'unoffered',
#   'status': 'solved',
#   'total_seconds': 2138,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51100.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-07-01T00:03:15Z',
#   'id': 51205,
#   'satisfaction_rating': 'unoffered',
#   'status': 'open',
#   'total_seconds': 1147,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51205.json'},
#  {'assignee_id': None,
#   'created_at': '2021-06-17T20:22:35Z',
#   'id': 51115,
#   'satisfaction_rating': 'unoffered',
#   'status': 'hold',
#   'total_seconds': 1864,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51115.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-22T14:11:08Z',
#   'id': 51135,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 527,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51135.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-30T14:20:22Z',
#   'id': 51195,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 24,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51195.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-29T15:31:15Z',
#   'id': 51181,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 2602,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51181.json'},
#  {'assignee_id': None,
#   'created_at': '2021-06-01T15:04:22Z',
#   'id': 50937,
#   'satisfaction_rating': 'unoffered',
#   'status': 'deleted',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50937.json'},
#  {'assignee_id': None,
#   'created_at': '2021-07-01T12:45:48Z',
#   'id': 51208,
#   'satisfaction_rating': 'unoffered',
#   'status': 'hold',
#   'total_seconds': 711,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51208.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-07-01T15:49:38Z',
#   'id': 51211,
#   'satisfaction_rating': 'unoffered',
#   'status': 'open',
#   'total_seconds': 233,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51211.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-30T15:05:46Z',
#   'id': 51196,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 1047,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51196.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-29T16:29:10Z',
#   'id': 51182,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 988,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51182.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-10T21:08:03Z',
#   'id': 51049,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 3063,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51049.json'},
#  {'assignee_id': None,
#   'created_at': '2021-07-01T15:55:02Z',
#   'id': 51213,
#   'satisfaction_rating': 'unoffered',
#   'status': 'deleted',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51213.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-29T21:40:47Z',
#   'id': 51191,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 622,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51191.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-16T16:16:20Z',
#   'id': 51091,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 7465,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51091.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-06-24T16:07:35Z',
#   'id': 51158,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 105,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51158.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-30T17:42:09Z',
#   'id': 51200,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 107,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51200.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-30T16:52:25Z',
#   'id': 51199,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 452,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51199.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-30T16:25:16Z',
#   'id': 51197,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 1430,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51197.json'},
#  {'assignee_id': None,
#   'created_at': '2021-07-01T18:46:38Z',
#   'id': 51215,
#   'satisfaction_rating': 'unoffered',
#   'status': 'deleted',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51215.json'},
#  {'assignee_id': None,
#   'created_at': '2021-06-29T20:31:38Z',
#   'id': 51189,
#   'satisfaction_rating': 'unoffered',
#   'status': 'pending',
#   'total_seconds': 833,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51189.json'},
#  {'assignee_id': 364605768451,
#   'created_at': '2021-06-29T21:04:39Z',
#   'id': 51190,
#   'satisfaction_rating': 'unoffered',
#   'status': 'solved',
#   'total_seconds': 288,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51190.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-23T12:41:17Z',
#   'id': 51147,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 595,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51147.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-04-06T21:24:09Z',
#   'id': 50408,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 5345,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50408.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-05-20T08:25:13Z',
#   'id': 50842,
#   'satisfaction_rating': 'unoffered',
#   'status': 'solved',
#   'total_seconds': 1720,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50842.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-05-20T16:19:03Z',
#   'id': 50845,
#   'satisfaction_rating': 'unoffered',
#   'status': 'pending',
#   'total_seconds': 675,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50845.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-29T23:45:00Z',
#   'id': 51193,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 517,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51193.json'},
#  {'assignee_id': None,
#   'created_at': '2021-06-30T00:58:19Z',
#   'id': 51194,
#   'satisfaction_rating': 'unoffered',
#   'status': 'open',
#   'total_seconds': 4586,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51194.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-02T04:18:45Z',
#   'id': 50944,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 3281,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50944.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-07-01T02:10:30Z',
#   'id': 51206,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 499,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51206.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-28T20:32:25Z',
#   'id': 51176,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 2057,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51176.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-24T17:38:16Z',
#   'id': 51161,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1394,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51161.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-06-08T07:50:34Z',
#   'id': 51002,
#   'satisfaction_rating': 'good',
#   'status': 'closed',
#   'total_seconds': 5194,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51002.json'},
#  {'assignee_id': None,
#   'created_at': '2021-06-02T10:37:53Z',
#   'id': 50945,
#   'satisfaction_rating': 'unoffered',
#   'status': 'deleted',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50945.json'},
#  {'assignee_id': None,
#   'created_at': '2021-07-01T15:53:28Z',
#   'id': 51212,
#   'satisfaction_rating': 'unoffered',
#   'status': 'open',
#   'total_seconds': 1298,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51212.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-09T12:44:06Z',
#   'id': 51023,
#   'satisfaction_rating': 'unoffered',
#   'status': 'solved',
#   'total_seconds': 1012,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51023.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-18T08:11:03Z',
#   'id': 51118,
#   'satisfaction_rating': 'unoffered',
#   'status': 'hold',
#   'total_seconds': 9779,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51118.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-07-01T12:17:47Z',
#   'id': 51207,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 173,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51207.json'},
#  {'assignee_id': 370585501572,
#   'created_at': '2021-06-10T21:39:50Z',
#   'id': 51050,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 486,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51050.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-25T13:02:45Z',
#   'id': 51165,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 8204,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51165.json'},
#  {'assignee_id': None,
#   'created_at': '2021-07-01T19:50:34Z',
#   'id': 51216,
#   'satisfaction_rating': 'unoffered',
#   'status': 'pending',
#   'total_seconds': 416,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51216.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-23T11:50:08Z',
#   'id': 51146,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1111,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51146.json'},
#  {'assignee_id': None,
#   'created_at': '2021-06-29T17:57:27Z',
#   'id': 51186,
#   'satisfaction_rating': 'unoffered',
#   'status': 'pending',
#   'total_seconds': 2862,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51186.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-07-01T13:49:48Z',
#   'id': 51210,
#   'satisfaction_rating': 'unoffered',
#   'status': 'solved',
#   'total_seconds': 748,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51210.json'},
#  {'assignee_id': None,
#   'created_at': '2021-07-02T14:47:55Z',
#   'id': 51219,
#   'satisfaction_rating': 'unoffered',
#   'status': 'hold',
#   'total_seconds': 1597,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51219.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-07-01T13:47:30Z',
#   'id': 51209,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 1187,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51209.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-28T13:55:54Z',
#   'id': 51171,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 675,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51171.json'},
#  {'assignee_id': None,
#   'created_at': '2021-07-01T21:29:41Z',
#   'id': 51217,
#   'satisfaction_rating': 'unoffered',
#   'status': 'pending',
#   'total_seconds': 137,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51217.json'},
#  {'assignee_id': None,
#   'created_at': '2021-06-30T19:17:46Z',
#   'id': 51201,
#   'satisfaction_rating': 'unoffered',
#   'status': 'pending',
#   'total_seconds': 2106,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51201.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-23T20:29:26Z',
#   'id': 51153,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 614,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51153.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-24T09:41:56Z',
#   'id': 51155,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 178,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51155.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-07-02T15:58:42Z',
#   'id': 51222,
#   'satisfaction_rating': 'unoffered',
#   'status': 'closed',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51222.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-07-02T15:55:07Z',
#   'id': 51221,
#   'satisfaction_rating': 'unoffered',
#   'status': 'solved',
#   'total_seconds': 325,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51221.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-25T15:51:07Z',
#   'id': 51167,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 76,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51167.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-30T16:35:15Z',
#   'id': 51198,
#   'satisfaction_rating': 'unoffered',
#   'status': 'solved',
#   'total_seconds': 2182,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51198.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-07-01T16:05:10Z',
#   'id': 51214,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 249,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51214.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-24T17:06:49Z',
#   'id': 51159,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1871,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51159.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-23T16:29:31Z',
#   'id': 51149,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 1536,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51149.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-30T21:28:13Z',
#   'id': 51203,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 1495,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51203.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-29T19:32:55Z',
#   'id': 51188,
#   'satisfaction_rating': 'unoffered',
#   'status': 'pending',
#   'total_seconds': 1649,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51188.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-25T18:02:44Z',
#   'id': 51169,
#   'satisfaction_rating': 'good',
#   'status': 'closed',
#   'total_seconds': 1935,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51169.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-11T16:23:06Z',
#   'id': 51057,
#   'satisfaction_rating': 'offered',
#   'status': 'open',
#   'total_seconds': 5058,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51057.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-05-18T14:28:59Z',
#   'id': 50823,
#   'satisfaction_rating': 'offered',
#   'status': 'open',
#   'total_seconds': 18402,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/50823.json'},
#  {'assignee_id': None,
#   'created_at': '2021-07-02T20:54:49Z',
#   'id': 51223,
#   'satisfaction_rating': 'unoffered',
#   'status': 'open',
#   'total_seconds': None,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51223.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-07-02T11:20:35Z',
#   'id': 51218,
#   'satisfaction_rating': 'unoffered',
#   'status': 'pending',
#   'total_seconds': 2429,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51218.json'},
#  {'assignee_id': 389367924132,
#   'created_at': '2021-06-22T16:48:24Z',
#   'id': 51141,
#   'satisfaction_rating': 'offered',
#   'status': 'closed',
#   'total_seconds': 682,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51141.json'},
#  {'assignee_id': None,
#   'created_at': '2021-07-02T15:08:28Z',
#   'id': 51220,
#   'satisfaction_rating': 'unoffered',
#   'status': 'open',
#   'total_seconds': 3542,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51220.json'},
#  {'assignee_id': 380454819451,
#   'created_at': '2021-06-30T20:47:47Z',
#   'id': 51202,
#   'satisfaction_rating': 'offered',
#   'status': 'solved',
#   'total_seconds': 1783,
#   'url': 'https://ambition.zendesk.com/api/v2/tickets/51202.json'}]
